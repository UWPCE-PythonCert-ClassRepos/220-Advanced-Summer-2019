# %%
import csv

from pymongo import MongoClient

mongo = MongoClient("mongodb://localhost:27017")
db = mongo["assignment"]


def import_data(data_dir, *files): #using args to import the multiple csv files
    for filepath in files:
        collection_name = filepath.split(".")[0]
        
        print("opening", "/".join([data_dir, filepath]))
        with open("/".join([data_dir, filepath])) as file:
            reader = csv.reader(file, delimiter=",")
            
            header = False
            for row in reader:
                if not header:
                    header = [h.strip("\ufeff") for h in row]
                else:
                    data = {header[i]:v for i,v in enumerate(row)}
                    print(data)
                    cursor = db[collection_name]
                    cursor.insert_one(data)


import_data("assignment/data", "product.csv", "customers.csv", "rental.csv")
# Out:
# opening assignment/data/product.csv
# {'product_id': 'prd001', 'description': '60-inch TV stand', 'product_type': 'livingroom', 'quantity_available': '3'}
# {'product_id': 'prd002', 'description': 'L-shaped sofa', 'product_type': 'livingroom', 'quantity_available': '0'}
# {'product_id': 'prd003', 'description': 'Acacia kitchen table', 'product_type': 'kitchen', 'quantity_available': '7'}
# {'product_id': 'prd004', 'description': 'Queen bed', 'product_type': 'bedroom', 'quantity_available': '10'}
# {'product_id': 'prd005', 'description': 'Reading lamp', 'product_type': 'bedroom', 'quantity_available': '20'}
# {'product_id': 'prd006', 'description': 'Portable heater', 'product_type': 'bathroom', 'quantity_available': '14'}
# {'product_id': 'prd007', 'description': 'Ballerina painting', 'product_type': 'livingroom', 'quantity_available': '0'}
# {'product_id': 'prd008', 'description': 'Smart microwave', 'product_type': 'kitchen', 'quantity_available': '30'}
# {'product_id': 'prd009', 'description': 'Popcorn machine', 'product_type': 'kitchen', 'quantity_available': '0'}
# {'product_id': 'prd010', 'description': '60-inch TV', 'product_type': 'livingroom', 'quantity_available': '3'}
# opening assignment/data/customers.csv
# {'user_id': 'user001', 'name': 'Elisa Miles', 'address': '4490 Union Street', 'zip_code': '98109', 'phone_number': '206-922-0882', 'email': 'elisa.miles@yahoo.com'}
# {'user_id': 'user002', 'name': 'Maya Data', 'address': '4936 Elliot Avenue', 'zip_code': '98115', 'phone_number': '206-777-1927', 'email': 'mdata@uw.edu'}
# {'user_id': 'user003', 'name': 'Andy Norris', 'address': '348 Terra Street', 'zip_code': '98501', 'phone_number': '206-309-2533', 'email': 'andy.norris@gmail.com'}
# {'user_id': 'user004', 'name': 'Flor Matatena', 'address': '885 Boone Crockett Lane', 'zip_code': '97209', 'phone_number': '206-414-2629', 'email': 'matseattle@pge.com'}
# {'user_id': 'user005', 'name': 'Dan Sounders', 'address': '861 Honeysuckle Lane', 'zip_code': '98244', 'phone_number': '206-279-1723', 'email': 'soundersoccer@mls.com'}
# {'user_id': 'user006', 'name': 'Leo Dembele', 'address': '2725 Mutton Town Road', 'zip_code': '98368', 'phone_number': '206-203-1294', 'email': 'leo.dembele@comcast.com'}
# {'user_id': 'user007', 'name': 'Pete Nicholas', 'address': '668 Elliot Avenue', 'zip_code': '98115', 'phone_number': '206-279-8759', 'email': 'nicholasp@amazon.com'}
# {'user_id': 'user008', 'name': 'Shirlene Harris', 'address': '4329 Honeysuckle Lane', 'zip_code': '98055', 'phone_number': '206-279-5340', 'email': 'harrisfamily@gmail.com'}
# {'user_id': 'user009', 'name': 'Nick Rather', 'address': '4679 Goodwin Avenue', 'zip_code': '98619', 'phone_number': '206-777-1965', 'email': 'nick.rather@microsoft.com'}
# {'user_id': 'user010', 'name': 'Jose Garza', 'address': '2717 Raccoon Run', 'zip_code': '98116', 'phone_number': '206-946-8200', 'email': 'joegarza@boeing.com'}
# opening assignment/data/rental.csv
# {'product_id': 'prd003', 'user_id': 'user004'}
# {'product_id': 'prd002', 'user_id': 'user008'}
# {'product_id': 'prd002', 'user_id': 'user005'}
# {'product_id': 'prd005', 'user_id': 'user001'}
# {'product_id': 'prd010', 'user_id': 'user002'}
# {'product_id': 'prd007', 'user_id': 'user002'}
# {'product_id': 'prd006', 'user_id': 'user003'}
# {'product_id': 'prd005', 'user_id': 'user003'}
# {'product_id': 'prd001', 'user_id': 'user010'}

# %%
cursor = db["product"]
list(cursor.find())
# Out:
# [{'_id': ObjectId('5d41062b0b1b4523352dda54'),
#   'product_id': 'prd001',
#   'description': '60-inch TV stand',
#   'product_type': 'livingroom',
#   'quantity_available': '3'},
#  {'_id': ObjectId('5d41062b0b1b4523352dda55'),
#   'product_id': 'prd002',
#   'description': 'L-shaped sofa',
#   'product_type': 'livingroom',
#   'quantity_available': '0'},
#  {'_id': ObjectId('5d41062b0b1b4523352dda56'),
#   'product_id': 'prd003',
#   'description': 'Acacia kitchen table',
#   'product_type': 'kitchen',
#   'quantity_available': '7'},
#  {'_id': ObjectId('5d41062b0b1b4523352dda57'),
#   'product_id': 'prd004',
#   'description': 'Queen bed',
#   'product_type': 'bedroom',
#   'quantity_available': '10'},
#  {'_id': ObjectId('5d41062b0b1b4523352dda58'),
#   'product_id': 'prd005',
#   'description': 'Reading lamp',
#   'product_type': 'bedroom',
#   'quantity_available': '20'},
#  {'_id': ObjectId('5d41062b0b1b4523352dda59'),
#   'product_id': 'prd006',
#   'description': 'Portable heater',
#   'product_type': 'bathroom',
#   'quantity_available': '14'},
#  {'_id': ObjectId('5d41062b0b1b4523352dda5a'),
#   'product_id': 'prd007',
#   'description': 'Ballerina painting',
#   'product_type': 'livingroom',
#   'quantity_available': '0'},
#  {'_id': ObjectId('5d41062b0b1b4523352dda5b'),
#   'product_id': 'prd008',
#   'description': 'Smart microwave',
#   'product_type': 'kitchen',
#   'quantity_available': '30'},
#  {'_id': ObjectId('5d41062b0b1b4523352dda5c'),
#   'product_id': 'prd009',
#   'description': 'Popcorn machine',
#   'product_type': 'kitchen',
#   'quantity_available': '0'},
#  {'_id': ObjectId('5d41062b0b1b4523352dda5d'),
#   'product_id': 'prd010',
#   'description': '60-inch TV',
#   'product_type': 'livingroom',
#   'quantity_available': '3'},
#  {'_id': ObjectId('5d41067a0b1b4523352dda69'),
#   'product_id': 'prd001',
#   'description': '60-inch TV stand',
#   'product_type': 'livingroom',
#   'quantity_available': '3'},
#  {'_id': ObjectId('5d41067a0b1b4523352dda6a'),
#   'product_id': 'prd002',
#   'description': 'L-shaped sofa',
#   'product_type': 'livingroom',
#   'quantity_available': '0'},
#  {'_id': ObjectId('5d41067a0b1b4523352dda6b'),
#   'product_id': 'prd003',
#   'description': 'Acacia kitchen table',
#   'product_type': 'kitchen',
#   'quantity_available': '7'},
#  {'_id': ObjectId('5d41067a0b1b4523352dda6c'),
#   'product_id': 'prd004',
#   'description': 'Queen bed',
#   'product_type': 'bedroom',
#   'quantity_available': '10'},
#  {'_id': ObjectId('5d41067a0b1b4523352dda6d'),
#   'product_id': 'prd005',
#   'description': 'Reading lamp',
#   'product_type': 'bedroom',
#   'quantity_available': '20'},
#  {'_id': ObjectId('5d41067a0b1b4523352dda6e'),
#   'product_id': 'prd006',
#   'description': 'Portable heater',
#   'product_type': 'bathroom',
#   'quantity_available': '14'},
#  {'_id': ObjectId('5d41067a0b1b4523352dda6f'),
#   'product_id': 'prd007',
#   'description': 'Ballerina painting',
#   'product_type': 'livingroom',
#   'quantity_available': '0'},
#  {'_id': ObjectId('5d41067a0b1b4523352dda70'),
#   'product_id': 'prd008',
#   'description': 'Smart microwave',
#   'product_type': 'kitchen',
#   'quantity_available': '30'},
#  {'_id': ObjectId('5d41067a0b1b4523352dda71'),
#   'product_id': 'prd009',
#   'description': 'Popcorn machine',
#   'product_type': 'kitchen',
#   'quantity_available': '0'},
#  {'_id': ObjectId('5d41067a0b1b4523352dda72'),
#   'product_id': 'prd010',
#   'description': '60-inch TV',
#   'product_type': 'livingroom',
#   'quantity_available': '3'},
#  {'_id': ObjectId('5d4106b20b1b4523352dda7e'),
#   'product_id': 'prd001',
#   'description': '60-inch TV stand',
#   'product_type': 'livingroom',
#   'quantity_available': '3'},
#  {'_id': ObjectId('5d4106b20b1b4523352dda7f'),
#   'product_id': 'prd002',
#   'description': 'L-shaped sofa',
#   'product_type': 'livingroom',
#   'quantity_available': '0'},
#  {'_id': ObjectId('5d4106b20b1b4523352dda80'),
#   'product_id': 'prd003',
#   'description': 'Acacia kitchen table',
#   'product_type': 'kitchen',
#   'quantity_available': '7'},
#  {'_id': ObjectId('5d4106b20b1b4523352dda81'),
#   'product_id': 'prd004',
#   'description': 'Queen bed',
#   'product_type': 'bedroom',
#   'quantity_available': '10'},
#  {'_id': ObjectId('5d4106b20b1b4523352dda82'),
#   'product_id': 'prd005',
#   'description': 'Reading lamp',
#   'product_type': 'bedroom',
#   'quantity_available': '20'},
#  {'_id': ObjectId('5d4106b20b1b4523352dda83'),
#   'product_id': 'prd006',
#   'description': 'Portable heater',
#   'product_type': 'bathroom',
#   'quantity_available': '14'},
#  {'_id': ObjectId('5d4106b20b1b4523352dda84'),
#   'product_id': 'prd007',
#   'description': 'Ballerina painting',
#   'product_type': 'livingroom',
#   'quantity_available': '0'},
#  {'_id': ObjectId('5d4106b20b1b4523352dda85'),
#   'product_id': 'prd008',
#   'description': 'Smart microwave',
#   'product_type': 'kitchen',
#   'quantity_available': '30'},
#  {'_id': ObjectId('5d4106b20b1b4523352dda86'),
#   'product_id': 'prd009',
#   'description': 'Popcorn machine',
#   'product_type': 'kitchen',
#   'quantity_available': '0'},
#  {'_id': ObjectId('5d4106b20b1b4523352dda87'),
#   'product_id': 'prd010',
#   'description': '60-inch TV',
#   'product_type': 'livingroom',
#   'quantity_available': '3'},
#  {'_id': ObjectId('5d4106e30b1b4523352dda93'),
#   'product_id': 'prd001',
#   'description': '60-inch TV stand',
#   'product_type': 'livingroom',
#   'quantity_available': '3'},
#  {'_id': ObjectId('5d4106e30b1b4523352dda94'),
#   'product_id': 'prd002',
#   'description': 'L-shaped sofa',
#   'product_type': 'livingroom',
#   'quantity_available': '0'},
#  {'_id': ObjectId('5d4106e30b1b4523352dda95'),
#   'product_id': 'prd003',
#   'description': 'Acacia kitchen table',
#   'product_type': 'kitchen',
#   'quantity_available': '7'},
#  {'_id': ObjectId('5d4106e30b1b4523352dda96'),
#   'product_id': 'prd004',
#   'description': 'Queen bed',
#   'product_type': 'bedroom',
#   'quantity_available': '10'},
#  {'_id': ObjectId('5d4106e30b1b4523352dda97'),
#   'product_id': 'prd005',
#   'description': 'Reading lamp',
#   'product_type': 'bedroom',
#   'quantity_available': '20'},
#  {'_id': ObjectId('5d4106e30b1b4523352dda98'),
#   'product_id': 'prd006',
#   'description': 'Portable heater',
#   'product_type': 'bathroom',
#   'quantity_available': '14'},
#  {'_id': ObjectId('5d4106e30b1b4523352dda99'),
#   'product_id': 'prd007',
#   'description': 'Ballerina painting',
#   'product_type': 'livingroom',
#   'quantity_available': '0'},
#  {'_id': ObjectId('5d4106e30b1b4523352dda9a'),
#   'product_id': 'prd008',
#   'description': 'Smart microwave',
#   'product_type': 'kitchen',
#   'quantity_available': '30'},
#  {'_id': ObjectId('5d4106e30b1b4523352dda9b'),
#   'product_id': 'prd009',
#   'description': 'Popcorn machine',
#   'product_type': 'kitchen',
#   'quantity_available': '0'},
#  {'_id': ObjectId('5d4106e30b1b4523352dda9c'),
#   'product_id': 'prd010',
#   'description': '60-inch TV',
#   'product_type': 'livingroom',
#   'quantity_available': '3'},
#  {'_id': ObjectId('5d4106fe0b1b4523352ddab1'),
#   'product_id': 'prd001',
#   'description': '60-inch TV stand',
#   'product_type': 'livingroom',
#   'quantity_available': '3'},
#  {'_id': ObjectId('5d4106fe0b1b4523352ddab2'),
#   'product_id': 'prd002',
#   'description': 'L-shaped sofa',
#   'product_type': 'livingroom',
#   'quantity_available': '0'},
#  {'_id': ObjectId('5d4106fe0b1b4523352ddab3'),
#   'product_id': 'prd003',
#   'description': 'Acacia kitchen table',
#   'product_type': 'kitchen',
#   'quantity_available': '7'},
#  {'_id': ObjectId('5d4106fe0b1b4523352ddab4'),
#   'product_id': 'prd004',
#   'description': 'Queen bed',
#   'product_type': 'bedroom',
#   'quantity_available': '10'},
#  {'_id': ObjectId('5d4106fe0b1b4523352ddab5'),
#   'product_id': 'prd005',
#   'description': 'Reading lamp',
#   'product_type': 'bedroom',
#   'quantity_available': '20'},
#  {'_id': ObjectId('5d4106fe0b1b4523352ddab6'),
#   'product_id': 'prd006',
#   'description': 'Portable heater',
#   'product_type': 'bathroom',
#   'quantity_available': '14'},
#  {'_id': ObjectId('5d4106fe0b1b4523352ddab7'),
#   'product_id': 'prd007',
#   'description': 'Ballerina painting',
#   'product_type': 'livingroom',
#   'quantity_available': '0'},
#  {'_id': ObjectId('5d4106fe0b1b4523352ddab8'),
#   'product_id': 'prd008',
#   'description': 'Smart microwave',
#   'product_type': 'kitchen',
#   'quantity_available': '30'},
#  {'_id': ObjectId('5d4106fe0b1b4523352ddab9'),
#   'product_id': 'prd009',
#   'description': 'Popcorn machine',
#   'product_type': 'kitchen',
#   'quantity_available': '0'},
#  {'_id': ObjectId('5d4106fe0b1b4523352ddaba'),
#   'product_id': 'prd010',
#   'description': '60-inch TV',
#   'product_type': 'livingroom',
#   'quantity_available': '3'}]
